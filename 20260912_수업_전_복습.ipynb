# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkLight0418/bdai_class/blob/main/20260912_%EC%88%98%EC%97%85_%EC%A0%84_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_a = [1, 2, 3, 4, 5]
list_b = ['a', 'b', 'c', 'd', 'e']

print(list_a)
print(list_b)
# Out:
# [1, 2, 3, 4, 5]
# ['a', 'b', 'c', 'd', 'e']

# %%
print(list(range(50, 0, -4)))
# Out:
# [50, 46, 42, 38, 34, 30, 26, 22, 18, 14, 10, 6, 2]

# %%
a = [23, 3, 16, 45, 11]
print(a[0], a[3])
print(a[-1], a[-3])
# Out:
# 23 45
# 11 16

# %%
list_hangeul = ['가', '나', '다', '라', '마', '바', '사']

# %%
list_hangeul = ['가', '나', '다', '라', '마', '바', '사']

print(list_hangeul[3])
print(list_hangeul[0:3])
print(list_hangeul[5:])
# Out:
# 라
# ['가', '나', '다']
# ['바', '사']

# %%
a = [23, 3, 16, 45, 11]

a.append(99)
print(a)
# Out:
# [23, 3, 16, 45, 11, 99]

# %%
a = [23, 3, 16, 45, 11]

a = a + [99]
print(a)
# Out:
# [23, 3, 16, 45, 11, 99]

# %%
a = [23, 3, 16, 45, 11]

del a[2]
print(a)
# Out:
# [23, 3, 45, 11]

# %%
a = [23, 3, 16, 45, 11]

a.remove(45)
print(a)
# Out:
# [23, 3, 16, 11]

# %%
list1 = [1, 3, 5, 7]
list2 = [2, 4, 8]

list2.append(list1[1])
print(list2)
# Out:
# [2, 4, 8, 3]

# %%
del list2[2]

print(list2)
# Out:
# [2, 40, 3]

# %%
list2[1] = list2[1] * 10

print(list2)
# Out:
# [2, 40, 8, 3]

# %%
dict_a = {  'v1' : 32,
            'l1' : [1, 2, 3],
            'd1' : {'a' :1, 'b' :2} }

print(dict_a)
dict_a.items()
# Out:
# {'v1': 32, 'l1': [1, 2, 3], 'd1': {'a': 1, 'b': 2}}
# dict_items([('v1', 32), ('l1', [1, 2, 3]), ('d1', {'a': 1, 'b': 2})])

# %%
print( dict_a['v1'])
print('=' * 30)

print( dict_a['l1'])
print( dict_a['l1'][:2])
print('=' * 30)

print( dict_a['d1'])
print( dict_a['d1']['a'])
# Out:
# 32
# ...
# [1, 2, 3]
# [1, 2]
# ...
# {'a': 1, 'b': 2}
# 1

# %%
member = {'name': ['한기영'], 'age': [49], 'gender': ['m']}

# %%
member['name2'] = ['김한재']
member['age2'] = [27]
member['gender2'] = ['m']

print(member)
# Out:
# {'name': ['한기영'], 'age': [49], 'gender': ['m'], 'name2': ['김한재'], 'age2': [27], 'gender2': ['m']}

# %%
print(member['age'] + member['age2'])
print(member['age'][0])
# Out:
# [49, 27]
# 49

# %%
import pandas as pd

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic_simple.csv'
data = pd.read_csv(path)

data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
# 5                                   Moran, Mr. James    male   NaN   8.4583
# ...

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data = pd.read_csv(path)
data.head(5)
# Out:
#    Attrition  Age              Department  DistanceFromHome  Education  \
# 0          0   33  Research & Development                 7          3
# 1          0   35  Research & Development                18          2
# 2          0   42  Research & Development                 6          3
# 3          0   46                   Sales                 2          3
# 4          1   22  Research & Development                 4          1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  JobSatisfaction  \
# 0             817                        3    Male                3
# 1            1412                        3    Male                4
# 2            1911                        3    Male                1
# 3            1204                        3  Female                1
# 4             593                        3    Male                3
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 0       Married          11691                   0       No
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

path2 = '/content/drive/MyDrive/airquality_simple.csv'
home = pd.read_csv(path2)

home.head(5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41    190.0   7.4    67      5    1
# 1     36    118.0   8.0    72      5    2
# 2     12    149.0  12.6    74      5    3
# 3     18    313.0  11.5    62      5    4
# 4     19      NaN  14.3    56      5    5

# %%
path3 = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data3 = pd.read_csv(path3)

data3.head(5)
# Out:
#    Attrition  Age              Department  DistanceFromHome  Education  \
# 0          0   33  Research & Development                 7          3
# 1          0   35  Research & Development                18          2
# 2          0   42  Research & Development                 6          3
# 3          0   46                   Sales                 2          3
# 4          1   22  Research & Development                 4          1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  JobSatisfaction  \
# 0             817                        3    Male                3
# 1            1412                        3    Male                4
# 2            1911                        3    Male                1
# 3            1204                        3  Female                1
# 4             593                        3    Male                3
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 0       Married          11691                   0       No
# ...

# %%
data3.tail(3)
# Out:
#       Attrition  Age              Department  DistanceFromHome  Education  \
# 1172          0   29  Research & Development                 9          3
# 1173          0   29                   Sales                 2          3
# 1174          0   43                   Sales                16          3
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  JobSatisfaction  \
# 1172            1558                        3    Male                3
# 1173             469                        4    Male                3
# 1174             327                        4  Female                4
#
#      MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 1172       Married           2451                   6       No
# 1173       Married           4649                   1       No
# 1174       Married          16064                   5      Yes
#
#       PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 1172                 18                 2                  5
# ...

# %%
data3.shape
# Out:
# (1175, 19)

# %%
print(data3.columns)
# Out:
# Index(['Attrition', 'Age', 'Department', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany'],
#       dtype='object')

# %%
list(data3)
# Out:
# ['Attrition',
#  'Age',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany']

# %%
data3.dtypes
# Out:
# Attrition                   int64
# Age                         int64
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                     object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# NumCompaniesWorked          int64
# OverTime                   object
# PercentSalaryHike           int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# dtype: object

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Attrition                1175 non-null   int64
#  1   Age                      1175 non-null   int64
#  2   Department               1175 non-null   object
#  3   DistanceFromHome         1175 non-null   int64
#  4   Education                1175 non-null   int64
#  5   EmployeeNumber           1175 non-null   int64
#  6   EnvironmentSatisfaction  1175 non-null   int64
#  7   Gender                   1175 non-null   object
#  8   JobSatisfaction          1175 non-null   int64
#  9   MaritalStatus            1175 non-null   object
#  10  MonthlyIncome            1175 non-null   int64
#  11  NumCompaniesWorked       1175 non-null   int64
#  12  OverTime                 1175 non-null   object
#  13  PercentSalaryHike        1175 non-null   int64
# ...

# %% [markdown]
# # (3) 기본 집계
# ### 부터 할 차례
